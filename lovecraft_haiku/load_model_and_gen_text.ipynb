# %%
# imports
import numpy as np
from pickle import load
# TF Keras
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding,LSTM,Dense,GRU
from tensorflow.keras.preprocessing.sequence import pad_sequences
# Random
import random
from random import randint
# Word stuff
import spacy
from spacy.matcher import Matcher
import syllapy

# %%
# create spacy object
nlp = spacy.load('en_core_web_lg')

# %%
# load tokenizer and text sequences
with open('hp_GRU_E125_200seq_tokenizer.pickle', 'rb') as f:
    tokenizer = load(f)
with open('hp_GRU_E125_200seq_txt_seqs.pickle','rb') as f:
    txt_seqs = load(f)

# %%
# create tokenizer sequences from text sequences
seqs = tokenizer.texts_to_sequences(txt_seqs)
# make them into an np array
seqs = np.array(seqs)
# find out sequence length
seq_len = seqs[:,:-1].shape[1]
# get the vocabulary size
vocab_size = len(tokenizer.word_counts)

# %%
def create_model(voc_size,s_len):
    model = Sequential()
    model.add(Embedding(voc_size,64,input_length=s_len))
    model.add(GRU(128,return_sequences=True))
    model.add(GRU(128))
    model.add(Dense(128,activation='relu'))
    model.add(Dense(voc_size,activation='softmax'))
    
    model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
    
    model.summary()
    
    return model

# %%
# create the base model and load weights
model = create_model(vocab_size+1,seq_len)
model.load_weights('hp_GRU_E125_200seq.h5')
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 200, 64)           771008
#
#  gru (GRU)                   (None, 200, 128)          74496
#
#  gru_1 (GRU)                 (None, 128)               99072
#
#  dense (Dense)               (None, 128)               16512
#
#  dense_1 (Dense)             (None, 12047)             1554063
#
# =================================================================
# Total params: 2,515,151
# Trainable params: 2,515,151
# Non-trainable params: 0
# _________________________________________________________________

# %%
# function to generate a block of text from where we will grab words to make a haiku
def generate_bunch(model,tokenizer,seq_len,text_sequences,num_words=300):
    # grab a random text sequence to serve as seed text 
    input_text = ' '.join(text_sequences[random.randint(0,len(text_sequences))])
    output_text = []
    # let's make 'num_words' many words
    for _ in range(num_words):
        # sequence our text so we can shove it into our model
        encoded_text = tokenizer.texts_to_sequences([input_text])[0]
        # pad the sequence (if needed) to match the sequence length
        pad_encoded = pad_sequences([encoded_text],maxlen=seq_len,truncating='pre')
        # predict the index of the most likely next word
        pred_word_ind = np.argmax(model.predict(pad_encoded,verbose=0)[0],axis=-1)
        # get the actual word from the index from the tokenizer
        pred_word = tokenizer.index_word[pred_word_ind]
        # add the new word to the seed text
        input_text += ' ' + pred_word
        # add the new word to the output text
        output_text.append(pred_word)
    return output_text

# %%
# create spacy matcher objects that we will use to search
# for patterns in haiku_words
m1 = Matcher(nlp.vocab)
m2 = Matcher(nlp.vocab)
m3 = Matcher(nlp.vocab)
m4 = Matcher(nlp.vocab)
m5 = Matcher(nlp.vocab)

# %%
# each pattern is a spacy pattern that searches for part-of-speech tags

# single word, word can only be ['noun','adp','adj','adv']
pattern = [{'POS':{'IN': ['NOUN','ADP','ADJ','ADV']}}]
m1.add('OneWords',[pattern])

# two words
pattern = [{'POS':{'IN': ['NOUN','ADP','ADJ','ADV']}},
           {'POS':{'IN': ['NOUN','VERB']}}]
m2.add('TwoWords',[pattern])

# three words, the second word can be any word
pattern = [{'POS': {'IN': ['NOUN','ADP','ADJ','ADV']}},
           {'IS_ASCII': True,'IS_PUNCT': False, 'IS_SPACE': False},
           {'POS': {'IN': ['NOUN','VERB','ADJ','ADV']}}]
m3.add("ThreeWords",[pattern])

# four words
pattern = [{'POS': {'IN': ['NOUN','ADP','ADJ','ADV']}},
           {'IS_ASCII': True,'IS_PUNCT': False, 'IS_SPACE': False},
           {'IS_ASCII': True,'IS_PUNCT': False, 'IS_SPACE': False},
           {'POS': {'IN': ['NOUN','VERB','ADJ','ADV']}}]
m4.add("FourWords",[pattern])

# five words
pattern = [{'POS': {'IN': ['NOUN','ADP','ADJ','ADV']}},
           {'IS_ASCII': True,'IS_PUNCT': False, 'IS_SPACE': False},
           {'IS_ASCII': True,'IS_PUNCT': False, 'IS_SPACE': False},
           {'IS_ASCII': True,'IS_PUNCT': False, 'IS_SPACE': False},
           {'POS': {'IN': ['NOUN','VERB','ADJ','ADV']}}]
m5.add("FiveWords",[pattern])

# %%
# make lists for number-of-syllables patterns
# 5 syllables
syl5 = []
# 7 syllables
syl7 = []

# %%
def find_syllables(document,syllable_list_1,syllable_list_2,
                  matcher1,matcher2,matcher3,matcher4,matcher5):
    # let the matcher objects search for patterns
    M1 = matcher1(document)
    M2 = matcher2(document)
    M3 = matcher3(document)
    M4 = matcher4(document)
    M5 = matcher5(document)
    # go through the matches and count the syllables
    for match_id,start,end in M1 + M2 + M3 + M4 + M5:
        string_id = nlp.vocab.strings[match_id]
        span = doc[start:end]

        syl_count = 0
        # count the syllables
        for token in span:
            syl_count += syllapy.count(token.text)
        # if syllables == 5 and the pattern is not in the list, add it
        if syl_count == 5:
            if span.text not in syllable_list_1:
                syllable_list_1.append(span.text)
        # if syllables == 7 and the pattern is not in the list, add it
        if syl_count == 7:
            if span.text not in syllable_list_2:
                syllable_list_2.append(span.text)

# %%
# generate num_batches randomly generated blocks of text
# and continually add syllable sequences to syl5 and syl7
num_batches = 15
for i in range(num_batches):

    # generate a word library for our haiku building
    haiku_words = generate_bunch(model,tokenizer,seq_len,txt_seqs)
    # make it into a single string
    haiku_words = ' '.join(haiku_words)

    # spacy reads the haiku_words
    doc = nlp(haiku_words)
    
    # find syllable patterns and add them to syl5 and syl7
    find_syllables(doc,syl5,syl7,m1,m2,m3,m4,m5)
    
    print("done with batch {} out of {}".format(i+1,num_batches))
# Out:
# done with batch 1 out of 15
# done with batch 2 out of 15
# done with batch 3 out of 15
# done with batch 4 out of 15
# done with batch 5 out of 15
# done with batch 6 out of 15
# done with batch 7 out of 15
# done with batch 8 out of 15
# done with batch 9 out of 15
# done with batch 10 out of 15
# done with batch 11 out of 15
# done with batch 12 out of 15
# done with batch 13 out of 15
# done with batch 14 out of 15
# done with batch 15 out of 15

# %%
# print the patterns we've found
print(syl5)
print('\n')
print(syl7)
# Out:
# ['undeniably known', 'ahead and again', 'of that catacombs', 'catacombs and ward', 'yet had run away', 'in the same colour', 'sight of the river', 'of the river put', 'down hart the maniac', 'inside nor it took', 'rains of which his face', 'belfry reflecting', 'in the horrible', 'places he bowed', 'left of what shadows', 'of what shadows switch', 'abnormality', 'glass overlooking', 'especially stone', 'building harboured', 'rapidly coloured', 'beyond the river', 'atop the hollow', 'bearded and finny', 'finny gnorri build', 'workroom their churches', 'churches was surely', 'surely to engulf', 'stock of medium', 'to the waterfront', 'to an outsider', 'former ones crossed', 'thing is certainly', 'text the shuttered', 'amidst my yeares', 'chips darkness became', 'town ancient pursuers', 'design and rapidly', 'city not very', 'curious or deep', 'above an effort', 'effort i feared', 'ice surmounting more', 'on the opal throne', 'hollow cliffs of glass', 'of what was never', 'tale ever not free', 'free or smoke quietly', 'though made any stock', 'affair must be far', 'nigh because he stood', 'ones crossed the coach', 'real that i looked', 'scared because i reached', 'off the chips darkness', 'panel in the hall', 'empty in my arms', 'far to be almost', 'sound of a design', 'skai that a new king', 'tour of my head so', 'of my head so most', 'so most of a thing', 'house of the town gorge', 'gorge though it was just', 'great part of my room', 'through that moon and grey', 'moon and grey and east', 'devil ever spoke', 'of water whispered', 'merwin or purpose', 'horror into speak', 'after some awful', 'so much of water', 'man or any so', 'down i am going', 'parts of all the men', 'long step from her own', 'step from her own half', 'from her own half part', 'half part that i seen', 'off some of the trees', 'terrible fashion', 'awful purgation', 'repellent series', 'presently i saw', 'fairly deep river', 'river gorge ahead', 'gorge ahead spanned', 'wide iron railed', 'toward the eastern', 'republic and saw', 'gardens something yet', 'in those terrible', 'peculiar brick smell', 'with a curious', 'map again reading', 'mother not complete', 'in another roof', 'buildings of chaos', 'chaos once hopping', 'resistance some time', 'toward the second', 'heads and emotions', 'emotions for hint', 'one therefore horror', 'sense of judicial', 'above and coming', 'unable to land', 'in any wooden', 'into the gilded', 'furtive children space', 'children space able', 'able as rapidly', 'dark gazette looking', 'by a wide iron', 'slabs beyond the high', 'order could not quite', 'yet heard it flashed', 'sounds in the houses', 'time it was very', 'side of a single', 'only a small sense', 'lock was a surface', 'plenty of a nest', 'out not doing think', 'after the third floor', 'marriage of a lean', 'showman was there so', 'deep that my feeling', 'baffling lest the dark', 'brick smell and the slow', 'smell and the slow sounds', 'for hint and sophie told', 'way a few too most', 'few too most the one', 'of a lean the boughs', 'various strokes', 'along the seventh', 'instead of keeping', 'behind a sudden', 'to the unknown church', 'men began to pass', 'shock was past taking', 'to his head curwen', 'feet from the latter', 'from that old wizard', 'in a malign look', 'cloud of fish instead', 'to the sea moonlight', 'sea moonlight an great', 'moonlight an great faint', 'death within it took', 'strokes who could find', 'sudden great tale found', 'bay to open old', 'at eight that the life', 'great tale found the bay', 'laboratory', 'documents proved', 'after providence', 'visible spires', 'health was destined', 'strange source connected', 'different and sought', 'of his documents', 'about the workmen', 'orchards he began', 'into the darkness', 'text had survived', 'as possible faint', 'about in order', 'order to avail', 'of imagine once', 'grandmother nor used', 'toward the zenith', 'of salem village', 'figures that stench', 'hope of secrecy', 'secrecy and old', 'old alter ...
#
#
# ['undeniably known little', 'unconsciously in the same', 'same colour the library', 'little to find a seaward', 'ahead and again once gone', 'of that catacombs and ward', 'quite any quite any rains', 'in some places he bowed', 'shadows switch but he urged', 'of medium probably', 'medium probably then', 'hurriedly from beginning', 'again the mortality', 'especially stone building', 'of the abnormality', 'ulthar beyond the river', 'fabulous town of turrets', 'turrets atop the hollow', 'cliffs of glass overlooking', 'bearded and finny gnorri', 'gnorri build their singular', 'outsider the former ones', 'coach i walked hurriedly', 'thing is certainly real', 'amidst my yeares forget', 'room to an especially', 'to an especially stone', 'stone building harboured more', 'pursuers we saw possible', 'possible dark voices far', 'very curious or deep', 'labyrinths or not so much', 'on the workroom their churches', 'former ones crossed the coach', 'from beginning for the side', 'of a thing is certainly', 'shuttered house of the town', 'of light amidst my yeares', 'off the chips darkness became', 'chips darkness became a great', 'darkness became a great part', 'town ancient pursuers we saw', 'voices far to be almost', 'far to be almost region', 'of a design and rapidly', 'curious or deep for fat', 'fat above the innsmouth look', 'effort i feared the ice', 'water whispered a healthy', 'somehow merwin or purpose', 'merwin or purpose lasted', 'purpose lasted a horror', 'ever spoke quite like away', 'so much of water whispered', 'lately buried on the woods', 'trees he was then tomorrow', 'repellent series outside', 'series outside together', 'albertus furtive children', 'more distinct and presently', 'river gorge ahead spanned', 'wide iron railed highway', 'iron railed highway bridge', 'beyond the high republic', 'in those terrible fashion', 'before and the peculiar', 'houses with a curious', 'again i can distinguish', 'with a awful purgation', 'one therefore horror only', 'one was almost unable', 'almost unable to land', 'in any wooden buildings', 'into the gilded marriage', 'furtive children space able', 'ahead spanned by a wide', 'by a wide iron railed', 'bridge light toward the eastern', 'toward the eastern and slabs', 'worst which hinted for gardens', 'for gardens something yet heard', 'fashion and toward the street', 'mother not complete a time', 'second side of a single', 'side of a single rapid', 'ninth of heads and emotions', 'heads and emotions for hint', 'horror only a small sense', 'of judicial as the lock', 'lock was a surface around', 'buildings after the third floor', 'gilded marriage of a lean', 'space able as rapidly s’pose', 'baffling lest the dark gazette', 'curious reality', 'seventh of occasional', 'occasional wild miasma', 'altogether on his back', 'wild miasma is visible', 'up sobbing and ethereal', 'wizard and a century', 'curwen did not have happened', 'body must be many feet', 'many feet from the latter', 'year borrowed from that old', 'of fish instead of keeping', 'of keeping an frantic note', 'behind a sudden great tale', 'attic laboratory', 'long railed conversation', 'conversation he started', 'workmen after providence', 'attention for cyclopean', 'cyclopean and dimensions', 'strange source connected settled', 'contents of his documents', 'of his documents proved', 'into the darkness below', 'possible faint and almost', 'once nothing this grandmother', 'toward the zenith marshes', 'region ammi had ever', 'village seemed first exchanged', 'only hope of secrecy', 'last the visible spires', 'visible spires and hung', 'about by what appeared', 'suggestion of bestial life', 'uncle ships sometimes worried', 'there his health was destined', 'sign different and sought signs', 'lips half about the workmen', 'crown and orchards he began', 'orchards he began to go', 'darkness below in the night', 'below in the night outside', 'almost voice and did others', 'here but after this fellow', 'parents shifted in the great', 'of josep ...

# %%
# print the size of the pattern lists
print(len(syl5))
print(len(syl7))
# Out:
# 361
# 267

# %%
# make some haikus
with open("Lovecrafts_haikus_vol_1.txt",'w') as f:
    for _ in range(50):
        f.write("{}\n{}\n{}".format(random.choice(syl5),random.choice(syl7),random.choice(syl5)))
        f.write('\n\n')

# %%
# print out the haikus
with open("Lovecrafts_haikus_vol_1.txt",'r') as f:
    print(f.read())
# Out:
# few too most the one
# knowledge of the sinister
# way a few too most
#
# above an effort
# several bulging rambles
# waters and swam sight
#
# of the manuxet
# recovering and the boughs
# in the river bank
#
# showman was there so
# beyond the high republic
# of imagine once
#
# to his head curwen
# almost all sorts of colour
# half part that i seen
#
# uncle ships sometimes
# upper eaten the slanting
# documents proved
#
# awful purgation
# to arkham john ward supposed
# terrible and old
#
# clumsily edges
# in those terrible fashion
# life and my uncle
#
# into the other
# curious situation
# thorough well gaunt find
#
# leagues of twilight
# of salem village seemed first
# scared because i reached
#
# in a terrible
# scraps to any disposal
# panel in the hall
#
# better do no use
# cyclopean and dimensions
# unable to land
#
# man or any so
# ulthar beyond the river
# surely to engulf
#
# different and sought
# ruins of the manuxet says
# of the manuxet
#
# stroke of a ancient
# sight to the bygone ashes
# skai that a new king
#
# in the incident
# crown and orchards he began
# of charles ward had fixed
#
# pawtuxet farmhouse
# cliffs of glass overlooking
# wholesome colours
#
# note of its furtive
# last the visible spires
# at eight that the life
#
# over a region
# about by what appeared
# room after very
#
# beyond the river
# drawer in the ancient line
# rapidly coloured
#
# skai that a new king
# alone throws its old uncle
# uncle ships sometimes
#
# buildings of college
# buildings after the third floor
# alone throws its old
#
# shock was past taking
# merwin or purpose lasted
# laboratory
#
# in which the lovely
# from week about in order
# with a curious
#
# of a lean the boughs
# gnorri build their singular
# though made any stock
#
# brick smell and the slow
# there of the periphery
# better do no use
#
# feet from the latter
# to arkham john ward supposed
# emotions for hint
#
# horror into speak
# of medium probably
# about a cracked
#
# resistance some time
# doin’ me of crazy captain
# plenty of a nest
#
# way a few too most
# of hideous resignation
# with a curious
#
# chips mending had come
# tippler west than a sudden
# ever been to light
#
# pawtuxet farmhouse
# very curious or deep
# signs of food apart
#
# lower falls i passed
# same colour the library
# reigns with curious
#
# sudden and remaining
# above all when its thorough
# voice and did others
#
# heads and emotions
# here as over a region
# thickly governor
#
# of college knowledge
# of hideous resignation
# of the manuxet
#
# building harboured
# scraps to any disposal
# better do no use
#
# scarcely escape
# about by what appeared
# from her own half part
#
# toward the eastern
# curious intensity
# chips mending had come
#
# roar of the lower
# tippler west than a sudden
# into the darkness
#
# sea moonlight an great
# impression at the corner
# especially stone
#
# stock of medium
# of light amidst my yeares
# public was frankly
#
# bearded and finny
# village seemed first exchanged
# death within it took
#
# alone throws its old
# thing is certainly real
# of imagine once
#
# very poignant straw
# ninth of heads and emotions
# presently i saw
#
# of water whispered
# up sobbing and ethereal
# scream from the waters
#
# empty in my arms
# of action though the others
# rains of which his face
#
# yet the departure
# messenger which had ever
# in a terrible
#
# of chalcedony
# curious intensity
# frenzy of hideous
#
# sense of judicial
# worst which hinted for gardens
# sight to the bygone
